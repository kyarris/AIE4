# %% [markdown]
# # LangSmith and Evaluation Overview with AI Makerspace
#
# Today we'll be looking at an amazing tool:
#
# [LangSmith](https://docs.smith.langchain.com/)!
#
# This tool will help us monitor, test, debug, and evaluate our LangChain applications - and more!
#
# We'll also be looking at a few Advanced Retrieval techniques along the way - and evaluate it using LangSmith!
#
# ✋BREAKOUT ROOM #2:
# - Task 1: Dependencies and OpenAI API Key
# - Task 2: LCEL RAG Chain
# - Task 3: Setting Up LangSmith
# - Task 4: Examining the Trace in LangSmith!
# - Task 5: Create Testing Dataset
# - Task 6: Evaluation

# %% [markdown]
# ## Task 1: Dependencies and OpenAI API Key
#
# We'll be using OpenAI's suite of models today to help us generate and embed our documents for a simple RAG system built on top of LangChain's blogs!

# %%
# !pip install langchain_core langchain_openai langchain_community langchain-qdrant qdrant-client langsmith openai tiktoken cohere lxml -qU

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %% [markdown]
# #### Asyncio Bug Handling
#
# This is necessary for Colab.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Task #2: Create a Simple RAG Application Using Qdrant, Hugging Face, and LCEL
#
# Now that we have a grasp on how LCEL works, and how we can use LangChain and Hugging Face to interact with our data - let's step it up a notch and incorporate Qdrant!

# %% [markdown]
# ## LangChain Powered RAG
#
# First and foremost, LangChain provides a convenient way to store our chunks and their embeddings.
#
# It's called a `VectorStore`!
#
# We'll be using QDrant as our `VectorStore` today. You can read more about it [here](https://qdrant.tech/documentation/).
#
# Think of a `VectorStore` as a smart way to house your chunks and their associated embedding vectors. The implementation of the `VectorStore` also allows for smarter and more efficient search of our embedding vectors - as the method we used above would not scale well as we got into the millions of chunks.
#
# Otherwise, the process remains relatively similar under the hood!
#
# We'll use a SiteMapLoader to scrape the LangChain blogs - which will serve as our data for today!

# %% [markdown]
# ### Data Collection
#
# We'll be leveraging the `SitemapLoader` to load our PDF directly from the web!

# %%
from langchain.document_loaders import SitemapLoader

documents = SitemapLoader(web_path="https://blog.langchain.dev/sitemap-posts.xml").load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Fetching pages: 100%|##########| 220/220 [00:11<00:00, 19.39it/s]

# %% [markdown]
# ### Chunking Our Documents

# %% [markdown]
# Let's do the same process as we did before with our `RecursiveCharacterTextSplitter` - but this time we'll use ~200 tokens as our max chunk size!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 0,
    length_function = len,
)

split_chunks = text_splitter.split_documents(documents)

# %%
len(split_chunks)
# Out:
# 4821

# %% [markdown]
# Alright, now we have 516 ~200 token long documents.
#
# Let's verify the process worked as intended by checking our max document length.

# %%
max_chunk_length = 0

for chunk in split_chunks:
  max_chunk_length = max(max_chunk_length, len(chunk.page_content))

print(max_chunk_length)
# Out:
# 499

# %% [markdown]
# Perfect! Now we can carry on to creating and storing our embeddings.

# %% [markdown]
# ### Embeddings and Vector Storage
#
# We'll use the `text-embedding-3-small` embedding model again - and `Qdrant` to store all our embedding vectors for easy retrieval later!

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai.embeddings import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

qdrant_vectorstore = Qdrant.from_documents(
    documents=split_chunks,
    embedding=embedding_model,
    location=":memory:"
)

# %% [markdown]
# Now let's set up our retriever, just as we saw before, but this time using LangChain's simple `as_retriever()` method!

# %%
qdrant_retriever = qdrant_vectorstore.as_retriever()

# %% [markdown]
# #### Back to the Flow

# %% [markdown]
# We're ready to move to the next step!

# %% [markdown]
# ### Setting up our RAG
#
# We'll use the LCEL we touched on earlier to create a RAG chain.
#
# Let's think through each part:
#
# 1. First we need to retrieve context
# 2. We need to pipe that context to our model
# 3. We need to parse that output
#
# Let's start by setting up our prompt again, just so it's fresh in our minds!

# %% [markdown]
# ####🏗️ Activity #2:
#
# Complete the prompt so that your RAG application answers queries based on the context provided, but *does not* answer queries if the context is unrelated to the query.

# %%
from langchain.prompts import ChatPromptTemplate

base_rag_prompt_template = """\
Answer the query based on the context, however if the query is not relevant to the context say 'nah bro'.

Context:
{context}

Question:
{question}
"""

base_rag_prompt = ChatPromptTemplate.from_template(base_rag_prompt_template)

# %% [markdown]
# We'll set our Generator - `gpt-4o` in this case - below!

# %%
from langchain_openai.chat_models import ChatOpenAI

base_llm = ChatOpenAI(model="gpt-4o-mini", tags=["base_llm"])

# %% [markdown]
# #### Our RAG Chain
#
# Notice how we have a bit of a more complex chain this time - that's because we want to return our sources with the response.
#
# Let's break down the chain step-by-step:
#
# 1. We invoke the chain with the `question` item. Notice how we only need to provide `question` since both the retreiver and the `"question"` object depend on it.
#   - We also chain our `"question"` into our `retriever`! This is what ultimately collects the context through Qdrant.
# 2. We assign our collected context to a `RunnablePassthrough()` from the previous object. This is going to let us simply pass it through to the next step, but still allow us to run that section of the chain.
# 3. We finally collect our response by chaining our prompt, which expects both a `"question"` and `"context"`, into our `llm`. We also, collect the `"context"` again so we can output it in the final response object.
#
# The key thing to keep in mind here is that we need to pass our context through *after* we've retrieved it - to populate the object in a way that doesn't require us to call it or try and use it for something else.

# %%
from operator import itemgetter
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough

retrieval_augmented_qa_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | qdrant_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": base_rag_prompt | base_llm, "context": itemgetter("context")}
)

# %% [markdown]
# Let's get a visual understanding of our chain!

# %%
# !pip install -qU grandalf

# %%
print(retrieval_augmented_qa_chain.get_graph().draw_ascii())
# Out:
#           +---------------------------------+
#           | Parallel<context,question>Input |
#           +---------------------------------+
#                     **            **
#                   **                **
#                 **                    **
#          +--------+                     **
#          | Lambda |                      *
#          +--------+                      *
#               *                          *
#               *                          *
#               *                          *
#   +----------------------+          +--------+
#   | VectorStoreRetriever |          | Lambda |
#   +----------------------+          +--------+
#                     **            **
#                       **        **
#                         **    **
#           +----------------------------------+
#           | Parallel<context,question>Output |
#           +----------------------------------+
#                             *
#                             *
#                             *
#               +------------------------+
#               | Parallel<context>Input |
#               +------------------------+
#                      ***        ***
#                     *              *
#                   **                **
#            +--------+          +-------------+
#            | Lambda |          | Passthrough |
#            +--------+          +-------------+
#                      ***        ***
#                         *      *
#                          **  **
#               +-------------------------+
#               | Parallel<context>Output |
#               +-------------------------+
#                             *
#                             *
#                             *
#           +---------------------------------+
#           | Parallel<response,context>Input |
#           +---------------------------------+
#                    **              ***
#                 ***                   **
#               **                        ***
# +--------------------+                     **
# | ChatPromptTemplate |                      *
# +--------------------+                      *
#            *                                *
#            *                                *
#            *                                *
#     +------------+                     +--------+
#     | ChatOpenAI |                     | Lambda |
#     +------------+*                  **+--------+
#                    **              **
#                      ***        ***
#                         **    **
#           +----------------------------------+
#           | Parallel<response,context>Output |
#           +----------------------------------+

# %% [markdown]
# Let's try another visual representation:
#
# ![image](https://i.imgur.com/Ad31AhL.png)

# %% [markdown]
# Let's test our chain out!

# %%
response = retrieval_augmented_qa_chain.invoke({"question" : "What's new in LangChain v0.2?"})

# %%
response["response"].content
# Out:
# 'LangChain v0.2 introduces several new features and improvements, including:\n\n1. Full separation of langchain and langchain-community.\n2. New and versioned documentation.\n3. A more mature and controllable agent framework.\n4. Improved standardization of the LLM interface, particularly around tool calling.\n5. Streaming support and over 30 new partner packages.\n\nThis pre-release focuses on enhancing the stability and security of LangChain, with a full release expected in a few weeks.'

# %%
for context in response["context"]:
  print("Context:")
  print(context)
  print("----")
# Out:
# Context:
# page_content='Four months ago, we released the first stable version of LangChain. Today, we are following up by announcing a pre-release of langchain v0.2.This release builds upon the foundation laid in v0.1 and incorporates community feedback. We’re excited to share that v0.2 brings: A much-desired full separation of langchain and langchain-community New (and versioned!) docs A more mature and controllable agent framework Improved LLM interface standardization, particularly around tool callingBetter' metadata={'source': 'https://blog.langchain.dev/langchain-v02-leap-to-stability/', 'loc': 'https://blog.langchain.dev/langchain-v02-leap-to-stability/', 'lastmod': '2024-05-16T22:26:07.000Z', '_id': 'af8d89cbbaab493da510c17123e75af2', '_collection_name': '366685dec9224264a5fdbeed3ddade8c'}
# ----
# Context:
# page_content='LangChain v0.2: A Leap Towards Stability
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# All Posts
#
#
#
#
# Case Studies
#
#
#
#
# In the Loop
#
#
#
#
# LangChain
#
#
#
#
# Docs
#
#
#
#
# Changelog
#
#
#
#
#
# Sign in
# Subscribe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LangChain v0.2: A Leap Towards Stability
# Today, we're announcing the pre-release of LangChain v0.2, which improves the stability and security of LangChain.
#
# 5 min read
# May 10, 2024' metadata={'source': 'https://blog.langchain.dev/langchain-v02-leap-to-stability/', 'loc': 'https://blog.langchain.dev/langchain-v02-leap-to-stability/', 'lastmod': '2024-05-16T22:26:07.000Z', '_id': 'c1f156778b8b4e129e6b8cc1320b7056', '_collection_name': '366685dec9224264a5fdbeed3ddade8c'}
# ----
# Context:
# page_content='LangChain v0.1.0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# All Posts
#
#
#
#
# Case Studies
#
#
#
#
# In the Loop
#
#
#
#
# LangChain
#
#
#
#
# Docs
#
#
#
#
# Changelog
#
#
#
#
#
# Sign in
# Subscribe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LangChain v0.1.0
#
# By LangChain
# 10 min read
# Jan 8, 2024' metadata={'source': 'https://blog.langchain.dev/langchain-v0-1-0/', 'loc': 'https://blog.langchain.dev/langchain-v0-1-0/', 'lastmod': '2024-02-09T21:45:58.000Z', '_id': '9febd83a4b0a4fff94c2e94dd730fedc', '_collection_name': '366685dec9224264a5fdbeed3ddade8c'}
# ----
# Context:
# page_content='streaming support30+ new partner packages.This is just a pre-release, with the full v0.2 release coming in a few weeks. Let’s dive into what langchain v0.2 will include.Embracing stability: The evolution of LangChain architectureOne of the most notable changes in langchain v0.2 is the decoupling of the langchain package from langchain-community. As a result, langchain-community now depends on langchain-core and langchain. This is a continuation of the work we began with langchain v0.1.0 to' metadata={'source': 'https://blog.langchain.dev/langchain-v02-leap-to-stability/', 'loc': 'https://blog.langchain.dev/langchain-v02-leap-to-stability/', 'lastmod': '2024-05-16T22:26:07.000Z', '_id': '59b753a1577e4f76969b1d081db255b0', '_collection_name': '366685dec9224264a5fdbeed3ddade8c'}
# ----

# %% [markdown]
# Let's see if it can handle a query that is totally unrelated to the source documents.

# %%
response = retrieval_augmented_qa_chain.invoke({"question" : "What is the airspeed velocity of an unladen swallow?"})

# %%
response["response"].content
# Out:
# 'nah bro'

# %% [markdown]
# ## Task 3: Setting Up LangSmith
#
# Now that we have a chain - we're ready to get started with LangSmith!
#
# We're going to go ahead and use the following `env` variables to get our Colab notebook set up to start reporting.
#
# If all you needed was simple monitoring - this is all you would need to do!

# %%
from uuid import uuid4

unique_id = uuid4().hex[0:8]

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"LangSmith - {unique_id}"

# %% [markdown]
# ### LangSmith API
#
# In order to use LangSmith - you will need a beta key, you can join the queue through the `Beta Sign Up` button on LangSmith's homepage!
#
# Join [here](https://www.langchain.com/langsmith)

# %%
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass('Enter your LangSmith API key: ')

# %% [markdown]
# Let's test our our first generation!

# %%
retrieval_augmented_qa_chain.invoke({"question" : "What is LangSmith?"}, {"tags" : ["Demo Run"]})['response']
# Out:
# AIMessage(content='LangSmith is a framework built on top of LangChain, designed to track and improve the performance of AI-powered products, particularly in the context of LLM (Large Language Model) applications. It offers features such as observability, rapid iteration in development, and an SDK that allows for fine-grain controls and customizability. LangSmith aims to enhance the user experience and provide robust support for LLM-powered QA processes.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 913, 'total_tokens': 998}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9722793223', 'finish_reason': 'stop', 'logprobs': None}, id='run-c8fbd358-a3ed-4d6e-8584-14716266c21f-0', usage_metadata={'input_tokens': 913, 'output_tokens': 85, 'total_tokens': 998})

# %% [markdown]
# ## Task 4: Examining the Trace in LangSmith!
#
# Head on over to your LangSmith web UI to check out how the trace looks in LangSmith!

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Include a screenshot of your trace and explain what it means.
#
# ![D5F1299E-B330-4980-B56A-D0402D091B4E.jpeg](attachment:D5F1299E-B330-4980-B56A-D0402D091B4E.jpeg)
#
# Langsmith is showing me the trace of my OpenAI call. It shows me if the call was successful, what the OpenAI input was as well as the output. It also gives me information like timestamps of the call as well as latency.

# %% [markdown]
# ## Task 5: Loading Our Testing Set

# %%
# !git clone https://github.com/AI-Maker-Space/DataRepository.git
# Out:
# fatal: destination path 'DataRepository' already exists and is not an empty directory.

# %%
import pandas as pd

test_df = pd.read_csv("DataRepository/langchain_blog_test_data.csv")

# %% [markdown]
# Now we can set up our LangSmith client - and we'll add the above created dataset to our LangSmith instance!
#
# > NOTE: Read more about this process [here](https://docs.smith.langchain.com/old/evaluation/faq/manage-datasets#create-from-list-of-values)

# %%
from langsmith import Client

client = Client()

dataset_name = "langchain_blog_test_data.csv"
dataset = client.create_dataset(
    dataset_name=dataset_name, description="LangChain Blog Test Questions"
)

for triplet in test_df.iterrows():
  triplet = triplet[1]
  client.create_example(
      inputs={"question" : triplet["question"], "context": triplet["context"]},
      outputs={"answer" : triplet["answer"]},
      dataset_id=dataset.id
  )

# %% [markdown]
# ## Task 6: Evaluation
#
# Now we can run the evaluation!
#
# We'll need to start by preparing some custom data preparation functions to ensure our chain works with the expected inputs/outputs from the `evaluate` process in LangSmith.
#
# > NOTE: More reading on this available [here](https://docs.smith.langchain.com/how_to_guides/evaluation/evaluate_llm_application#evaluate-a-langchain-runnable)

# %%
def prepare_data_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.outputs["answer"],
      "input" : example.inputs["question"]
  }

def prepare_data_noref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "input" : example.inputs["question"]
  }

def prepare_context_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.inputs["context"],
      "input" : example.inputs["question"]
  }

# %% [markdown]
# We'll be using a few custom evaluators to evaluate our pipeline, as well as a few "built in" methods!
#
# Check out the built-ins [here](https://docs.smith.langchain.com/reference/sdk_reference/langchain_evaluators)!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

cot_qa_evaluator = LangChainStringEvaluator("cot_qa", prepare_data=prepare_context_ref)

unlabeled_dopeness_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria" : {
            "dopeness" : "Is the answer to the question dope, meaning cool - awesome - and legit?"
        }
    },
    prepare_data=prepare_data_noref
)

labeled_score_evaluator = LangChainStringEvaluator(
    "labeled_score_string",
    config={
        "criteria": {
            "accuracy": "Is the generated answer the same as the reference answer?"
        },
    },
    prepare_data=prepare_data_ref
)

base_rag_results = evaluate(
    retrieval_augmented_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        ],
    experiment_prefix="Keane Rag Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Keane Rag Evaluation-dc890212' at:
# https://smith.langchain.com/o/4338cd48-b435-5ef7-a0a2-2783f35f7872/datasets/bea9e3ac-0a78-4b56-9f47-8ddc33d0b45d/compare?selectedSessions=38c1761e-2f53-44d1-9cff-55ab3c3c3d4c
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run fcebf0de-5b84-40cb-8aa3-f270b91722d8: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9963, Requested 370. Please try again in 1.998s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 445, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9963, Requested 370. Please try again in 1.998s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 4fb7cbc0-dc5c-4e8a-b079-4663da2cd303: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9962, Requested 348. Please try again in 1.86s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 445, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9962, Requested 348. Please try again in 1.86s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 69c9115d-8544-44ac-8eaf-fa8f8270165e: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9851, Requested 989. Please try again in 5.04s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 303, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9851, Requested 989. Please try again in 5.04s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run a2ed692e-baef-47cf-a2b5-6ef4cfd96e36: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9642, Requested 363. Please try again in 30ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 445, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9642, Requested 363. Please try again in 30ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 61f9dfe6-4bbc-4388-acde-639de3608c72: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9948, Requested 414. Please try again in 2.172s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 445, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9948, Requested 414. Please try again in 2.172s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run f7c0f92e-fded-4138-850b-0049a4e74947: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9843, Requested 1353. Please try again in 7.176s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 303, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9843, Requested 1353. Please try again in 7.176s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run f8388f10-f47a-4a54-95bc-849aafc34298: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9877, Requested 372. Please try again in 1.494s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 445, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9877, Requested 372. Please try again in 1.494s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 92c2dbd7-becb-43f0-8671-a94f6860fff8: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9913, Requested 1516. Please try again in 8.574s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 303, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9862, Requested 686. Please try again in 3.288s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2bec7645-229a-49d5-9de3-392df664d5f5: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9818, Requested 698. Please try again in 3.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 351, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9818, Requested 698. Please try again in 3.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 207d8af5-b85a-4e2d-a530-690e7a5bbe04: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9432, Requested 728. Please try again in 960ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1313, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 609, in wrapper
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 606, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 260, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 220, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 351, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 180, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 381, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 164, in invoke
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/base.py", line 154, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     raise e
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 623, in generate
#     self._generate_with_cache(
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 845, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 635, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 274, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 668, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1260, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 937, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1026, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1075, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/keaneyarris/anaconda3/envs/aiw2/lib/python3.11/site-packages/openai/_base_client.py", line 1041, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-r5IbaZj7rUT7Fql6ogbxJHIU on tokens per min (TPM): Limit 10000, Used 9432, Requested 728. Please try again in 960ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# #### ❓Question #1:
#
# What conclusions can you draw about the above results?
#
# Describe in your own words what the metrics are expressing.
#
# In addition to the metrics that are shown for call success and latency, you can also see that with my Reference output, some of the calls failed as "incorrect" in the contextual accuracy tag for example the authors of "Origin" Reference output was not contextually similar according to the rag evaluation.
